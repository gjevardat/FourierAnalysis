# %%
import matplotlib.pyplot as plt
import numpy as np
import utils

# %%
period = 1
x, dx, f = utils.triangle_function(dx=0.01,P = period, x0=1)
harmonic_number = 20
A,B,freqs,H,SUM = utils.compute_fourrier_coef(f,x,dx,period,harmonic_number)

utils.plot_fourier(f,x,A,B,freqs,H,SUM,harmonic_number)
# Out:
# 0.25

# %%
x, dx, f = utils.square_function()
harmonic_number = 50
period = 1
A,B,freqs,H,SUM = utils.compute_fourrier_coef(f,x,dx,period,harmonic_number)

utils.plot_fourier(f,x,A,B,freqs,H,SUM,harmonic_number)
# Out:
# 1.02

# %%
period = np.pi
x, dx, f = utils.triangle_function(dx=0.01,P = period, x0=1)

harmonic_number = 100
A,B,freqs,H,SUM = utils.compute_fourrier_coef(f,x,dx,period,harmonic_number)

utils.plot_fourier(f,x,A,B,freqs,H,SUM,harmonic_number)
# Out:
# 0.24828171122335674
